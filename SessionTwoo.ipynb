# %%
num = 200

# %%
if (num>100):
    print(num)
elif():
    print("The number does not exist")
# Out:
# 200

# %%
array= ["one", "two"]
for x in range(5):
    print("AI")
# Out:
# AI
# AI
# AI
# AI
# AI

# %%
#whileloop
count=0
while(count<5):
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#append and insert
number=[1,2,"one", "two"]
number.append(3)
print(number[4])
print(number[-2])
print(number[0])
number.insert(0,0)
print(number[0])
# Out:
# 3
# two
# 1
# 0

# %%
#take input
Take=input("insert the first variable")
Take2=input("insert the second variable")
sum=int(Take)+int(Take2)
print(sum)
# Out:
# insert the first variable 2
# insert the second variable 8
# 10

# %%
#function
def add(a,b):
    return a+b
print(add(7,9))
# Out:
# 16

# %%
#largest
n=[4,7,9,16,8,27]
largest=n[0]
for m in n:
    if m > largest :
        largest=m
print(largest)
# Out:
# 27

# %%
#sum
n=[4,7,9,16,8,2]
total=0
for m in n:
    total+= m
print(total)
# Out:
# 46

# %%
#average
n=[4,7,9,16,8,2]
total=0
for m in n:
    total+=m
length=len(n)
Average=total/length
print(Average)
# Out:
# 7.666666666666667

# %%
#tuple and list
#dataTuble=(1,2,3,4,6)
data=[1,2,"Feven"]
data.pop()
data
data.append(3)
data
# Out:
# [1, 2, 3]

# %%
language=["C++", "java","php"]
