# %%
import pandas as pd

# %%
csv=pd.read_csv("testss.csv")

# %%
df=pd.DataFrame(csv)

# %%
print (df)
# Out:
#        #   Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0      1             USA   111820082       NaN    1219487.0        NaN
# 1      2           India    45035393       NaN     533570.0        NaN
# 2      3          France    40138560       NaN     167642.0        NaN
# 3      4         Germany    38828995       NaN     183027.0        NaN
# 4      5          Brazil    38743918       NaN     711380.0        NaN
# ..   ...             ...         ...       ...          ...        ...
# 226  227         Tokelau          80       NaN          NaN        NaN
# 227  228    Vatican City          29       NaN          NaN        NaN
# 228  229  Western Sahara          10       NaN          1.0        NaN
# 229  230      MS Zaandam           9       NaN          2.0        NaN
# 230  231           China      503302       NaN       5272.0        NaN
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  ...  \
# ...

# %%
df[df['Country,Other'] == 'Ethiopia']
# Out:
#      # Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 91  92      Ethiopia      501157       NaN       7574.0        NaN
#
#     TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  ...  \
# 91        488171.0           NaN       5412.0               NaN  ...
#
#     TotalTests  Tests/1M pop   Population  Continent  1 Caseevery X ppl  \
# 91   5565340.0       46066.0  120812698.0     Africa              241.0
#
#    1 Deathevery X ppl  1 Testevery X ppl  New Cases/1M pop  New Deaths/1M pop  \
# 91            15951.0               22.0               NaN                NaN
#
#     Active Cases/1M pop
# 91                 45.0
#
# [1 rows x 22 columns]

# %%
#Total death in ethiopia
df.loc[df['Country,Other'] == 'Ethiopia', ['Country,Other', 'TotalDeaths']]
# Out:
#    Country,Other  TotalDeaths
# 91      Ethiopia       7574.0

# %%
#Top 10 countries with highest total death
df[['Country,Other', 'TotalDeaths']].sort_values('TotalDeaths',ascending=False).head(10)
# Out:
#    Country,Other  TotalDeaths
# 0            USA    1219487.0
# 4         Brazil     711380.0
# 1          India     533570.0
# 9         Russia     402756.0
# 17        Mexico     334958.0
# 8             UK     232112.0
# 34          Peru     222161.0
# 7          Italy     196487.0
# 3        Germany     183027.0
# 2         France     167642.0

# %%
df[['Country,Other', 'TotalRecovered']].sort_values('TotalRecovered',ascending=False).head(10)
# Out:
#    Country,Other  TotalRecovered
# 0            USA     109814428.0
# 2         France      39970918.0
# 3        Germany      38240600.0
# 4         Brazil      36249161.0
# 5       S. Korea      34535939.0
# 7          Italy      26361218.0
# 8             UK      24678275.0
# 9         Russia      23545818.0
# 11         Spain      13762417.0
# 12     Australia      11820014.0

# %%
#using iloc
test=(df['TotalDeaths'] > 1000).sum()
print(test)
test_iloc=df['TotalDeaths'] 
print(test_iloc.iloc[1])
# Out:
# 133
# 533570.0

# %%
df.isnull()
# Out:
#          #  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0    False          False       False      True        False       True
# 1    False          False       False      True        False       True
# 2    False          False       False      True        False       True
# 3    False          False       False      True        False       True
# 4    False          False       False      True        False       True
# ..     ...            ...         ...       ...          ...        ...
# 226  False          False       False      True         True       True
# 227  False          False       False      True         True       True
# 228  False          False       False      True        False       True
# 229  False          False       False      True        False       True
# 230  False          False       False      True        False       True
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  ...  \
# ...

# %%
df[df['Country,Other'].str.contains('a')]
# Out:
#        #   Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 1      2           India    45035393       NaN     533570.0        NaN
# 2      3          France    40138560       NaN     167642.0        NaN
# 3      4         Germany    38828995       NaN     183027.0        NaN
# 4      5          Brazil    38743918       NaN     711380.0        NaN
# 5      6        S. Korea    34571873       NaN      35934.0        NaN
# ..   ...             ...         ...       ...          ...        ...
# 226  227         Tokelau          80       NaN          NaN        NaN
# 227  228    Vatican City          29       NaN          NaN        NaN
# 228  229  Western Sahara          10       NaN          1.0        NaN
# 229  230      MS Zaandam           9       NaN          2.0        NaN
# 230  231           China      503302       NaN       5272.0        NaN
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  ...  \
# ...
